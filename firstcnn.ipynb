# %% [markdown]
# <a href="https://colab.research.google.com/github/Sridatta-Satuluri/UMDAOSC650/blob/main/firstcnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Maintained at: https://github.com/mariajmolina/UMDAOSC650/blob/main/firstcnn.ipynb

# %% [markdown]
# # Our first convolutional neural network (CNN)!

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import keras
from keras import layers

# %% [markdown]
# We will use a dataset from Molina et al. (2021) consisting of thunderstorms generated using a 4-km horizontal resolution WRF simulation. We are using a small portion of the dataset, specifically thunderstorms simulated for April 27, 2011 over the continental United States.

# %%
# !wget https://zenodo.org/records/10576726/files/current_SP3hourly_20110427.nc
# Out:
# --2026-03-05 17:38:24--  https://zenodo.org/records/10576726/files/current_SP3hourly_20110427.nc
# Resolving zenodo.org (zenodo.org)... 188.184.98.114, 137.138.52.235, 188.184.103.118, ...
# Connecting to zenodo.org (zenodo.org)|188.184.98.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 109400556 (104M) [application/octet-stream]
# Saving to: ‘current_SP3hourly_20110427.nc’
#
# current_SP3hourly_2 100%[===================>] 104.33M  25.9MB/s    in 4.2s
#
# 2026-03-05 17:38:29 (24.7 MB/s) - ‘current_SP3hourly_20110427.nc’ saved [109400556/109400556]

# %% [markdown]
# Here we have some helper functions for normalizing and standardizing our data using numpy.

# %%
def scale_da_along_dim(
    da: xr.DataArray,
    dim: str = "feature",
    scaler=None,
    method: str = "standard",
    with_mean: bool = True,
    with_std: bool = True,
    feature_range=(0.0, 1.0),
):
    """
    Scale an xarray.DataArray along one dimension using sklearn,
    preserving xarray metadata and avoiding stack/unstack (duplicates OK).

    All dimensions except `dim` are treated as samples. One global scaler
    is fit across the entire array (per-feature statistics).

    Parameters
    ----------
    da : xr.DataArray
        Input data.
    dim : str
        Name of the feature dimension (e.g. "feature").
    scaler : sklearn transformer or None
        If None, a new scaler is created based on `method`.
        If provided, it is used for transform only (no re-fit).
        Must implement `.transform()` / `.fit_transform()`.
    method : {"standard", "minmax"}
        - "standard" -> sklearn.preprocessing.StandardScaler
        - "minmax"   -> sklearn.preprocessing.MinMaxScaler
    with_mean, with_std : bool
        Used only when method="standard" and scaler is None.
    feature_range : tuple
        Used only when method="minmax" and scaler is None.

    Returns
    -------
    da_scaled : xr.DataArray
        Same shape/dims/coords/attrs as `da`, scaled along `dim`.
    scaler : sklearn transformer
        The fitted scaler.
    """
    # 1) Make sure `dim` exists
    if dim not in da.dims:
        raise ValueError(f"Dimension {dim!r} not found in DataArray dims {da.dims!r}")

    # 2) Put `dim` last
    da_t = da.transpose(..., dim)
    feature_axis = da_t.get_axis_num(dim)  # should be -1

    # 3) Extract ndarray and move feature axis to last (for safety)
    data = da_t.values
    data_moved = np.moveaxis(data, feature_axis, -1)  # shape: (*sample_shape, n_features)

    # 4) Flatten all non-feature dims into samples
    orig_shape = data_moved.shape
    n_features = orig_shape[-1]
    n_samples = int(np.prod(orig_shape[:-1]))
    data_flat = data_moved.reshape(n_samples, n_features)  # (n_samples, n_features)

    # 5) Fit/transform with chosen scaler
    if scaler is None:
        if method == "standard":
            scaler = StandardScaler(with_mean=with_mean, with_std=with_std)
        elif method == "minmax":
            scaler = MinMaxScaler(feature_range=feature_range)
        else:
            raise ValueError("method must be 'standard' or 'minmax'")

        data_flat_scaled = scaler.fit_transform(data_flat)
    else:
        # reuse provided scaler
        data_flat_scaled = scaler.transform(data_flat)

    # 6) Reshape back and restore axes
    data_scaled_moved = data_flat_scaled.reshape(orig_shape)
    data_scaled_full = np.moveaxis(data_scaled_moved, -1, feature_axis)

    # 7) Wrap back into DataArray
    da_scaled_t = xr.DataArray(
        data_scaled_full,
        coords=da_t.coords,
        dims=da_t.dims,
        attrs=da.attrs,
        name=da.name,
    )

    # 8) Restore original dim order
    da_scaled = da_scaled_t.transpose(*da.dims)

    return da_scaled, scaler

def inverse_scale_da_along_dim(
    da_scaled: xr.DataArray,
    dim: str,
    scaler,
) -> xr.DataArray:
    """
    Inverse of `scale_da_along_dim`: apply scaler.inverse_transform and
    reconstruct the original DataArray with metadata.

    Works with any sklearn-like scaler that implements `inverse_transform`,
    e.g., StandardScaler or MinMaxScaler.
    """
    if dim not in da_scaled.dims:
        raise ValueError(f"Dimension {dim!r} not found in DataArray dims {da_scaled.dims!r}")

    # 1) Put `dim` last
    da_t = da_scaled.transpose(..., dim)
    feature_axis = da_t.get_axis_num(dim)

    # 2) Move feature axis to last and flatten other dims
    data = da_t.values
    data_moved = np.moveaxis(data, feature_axis, -1)
    orig_shape = data_moved.shape
    n_features = orig_shape[-1]
    n_samples = int(np.prod(orig_shape[:-1]))

    data_flat = data_moved.reshape(n_samples, n_features)

    # 3) Inverse transform
    data_flat_unscaled = scaler.inverse_transform(data_flat)

    # 4) Reshape back and restore axes
    data_unscaled_moved = data_flat_unscaled.reshape(orig_shape)
    data_unscaled_full = np.moveaxis(data_unscaled_moved, -1, feature_axis)

    # 5) Wrap into DataArray and restore original dim order
    da_unscaled_t = xr.DataArray(
        data_unscaled_full,
        coords=da_t.coords,
        dims=da_t.dims,
        attrs=da_scaled.attrs,
        name=da_scaled.name,
    )
    da_unscaled = da_unscaled_t.transpose(*da_scaled.dims)
    return da_unscaled

# %% [markdown]
# ## **Supervised Learning Regression Example**

# %% [markdown]
# Now, we will proceed with training a neural network in a supervised learning regression application.

# %% [markdown]
# Let's visualize the dataset. We can use python libraries for this.

# %%
ds = xr.open_dataset('current_SP3hourly_20110427.nc')

# %%
ds
# Out:
# <xarray.Dataset> Size: 109MB
# Dimensions:      (starttime: 2224, y: 32, x: 32)
# Coordinates:
#   * starttime    (starttime) float64 18kB 9.264e+04 9.264e+04 ... 9.266e+04
#     endtime      (starttime) float64 18kB ...
#     x_speed      (starttime) int64 18kB ...
#     y_speed      (starttime) int64 18kB ...
# Dimensions without coordinates: y, x
# Data variables:
#     uh25_grid    (starttime, y, x) float32 9MB ...
#     uh03_grid    (starttime, y, x) float32 9MB ...
#     ctt_grid     (starttime, y, x) float32 9MB ...
#     dbz_grid     (starttime, y, x) float32 9MB ...
#     mask         (starttime, y, x) int64 18MB ...
#     row_indices  (starttime, y, x) int64 18MB ...
#     col_indices  (starttime, y, x) int64 18MB ...
#     lats         (starttime, y, x) float32 9MB ...
#     lons         (starttime, y, x) float32 9MB ...

# %% [markdown]
# The dataset contains 2,224 storm samples that were generated using the github reposity [deep-conus](https://github.com/mariajmolina/deep-conus). Each sample is 32x32 grid cells (i.e., pixels) with each grid cell spanning 4-km.
#
# Let's visualize some of the variables.

# %%
# simulated radar reflectivity
ds['dbz_grid'].isel(starttime=0).plot()

# %%
# gridded updraft helicity from 2-5 km
ds['uh25_grid'].isel(starttime=0).plot()

# %%
# gridded cloud top temperature
ds['ctt_grid'].isel(starttime=0).plot()

# %% [markdown]
# Now we will preprocess our training and testing data. We need to split our data into a training and testing sets, and standardize.

# %%
# first contactenate multiple feature into one new array along a dim
tmp_dbz = ds['dbz_grid'].expand_dims(dim='feature', axis=3)
tmp_ctt = ds['ctt_grid'].expand_dims(dim='feature', axis=3)

features = xr.concat([tmp_dbz, tmp_ctt], dim='feature')

# %%
print(features.shape) # samples, x, y, features
# Out:
# (2224, 32, 32, 2)

# %%
# grab the maximum of the dbz to use as our labels (regression)
labels = ds['dbz_grid'].expand_dims(dim='feature', axis=3).max('x').max('y')

# %%
labels
# Out:
# <xarray.DataArray 'dbz_grid' (starttime: 2224, feature: 1)> Size: 9kB
# array([[65.721054],
#        [58.54062 ],
#        [58.54062 ],
#        ...,
#        [45.41483 ],
#        [37.786957],
#        [42.48563 ]], dtype=float32)
# Coordinates:
#   * starttime  (starttime) float64 18kB 9.264e+04 9.264e+04 ... 9.266e+04
#     endtime    (starttime) float64 18kB ...
#     x_speed    (starttime) int64 18kB ...
#     y_speed    (starttime) int64 18kB ...
# Dimensions without coordinates: feature

# %%
features
# Out:
# <xarray.DataArray 'dbz_grid' (starttime: 2224, y: 32, x: 32, feature: 2)> Size: 18MB
# array([[[[-35.        ,  30.846277  ],
#          [-35.        ,  30.279108  ],
#          [-35.        ,  29.919764  ],
#          ...,
#          [-11.190116  ,  24.125116  ],
#          [-10.856109  ,  24.160944  ],
#          [-10.487292  ,  24.194544  ]],
#
#         [[-35.        ,  30.6896    ],
#          [-35.        ,  30.205988  ],
#          [-35.        ,  29.94436   ],
#          ...,
#          [ -7.7814693 ,  24.12179   ],
#          [ -7.321682  ,  24.138666  ],
#          [ -6.878763  ,  24.156153  ]],
#
#         [[-35.        ,  30.631739  ],
#          [-35.        ,  30.26684   ],
#          [-35.        ,  30.094019  ],
#          ...,
# ...
#          ...,
#          [ 33.900024  ,   6.4582763 ],
#          [ 32.759426  ,   6.7443175 ],
#          [ 25.732063  ,   6.800195  ]],
#
#         [[ 15.411227  ,  11.729609  ],
#          [ 15.097066  ,  11.5689945 ],
#          [ 25.667683  ,  11.157282  ],
#          ...,
#          [ 30.886953  ,   6.4143615 ],
#          [ 28.967316  ,   6.7860045 ],
#          [ 26.899176  ,   6.865045  ]],
#
#         [[ 14.829235  ,  11.844446  ],
#          [ 16.460741  ,  11.534296  ],
#          [ 27.397823  ,  11.142817  ],
#          ...,
#          [ 25.714262  ,   6.4862304 ],
#          [ 23.523518  ,   6.860742  ],
#          [ 26.171114  ,   6.9690795 ]]]], dtype=float32)
# Coordinates:
#   * starttime  (starttime) float64 18kB 9.264e+04 9.264e+04 ... 9.266e+04
#     endtime    (starttime) float64 18kB 9.264e+04 9.264e+04 ... 9.266e+04
#     x_speed    (starttime) int64 18kB 0 0 0 0 0 0 0 0 ... -28 -4 -20 1 11 15 3 1
#     y_speed    (starttime) int64 18kB 0 0 0 0 0 0 0 0 ... 17 21 -1 -9 30 13 -3
# Dimensions without coordinates: y, x, feature

# %%
# make features, x, and y into one column, so that data is (samples, newdim) for train/test split func to work
features_1d = features.stack(newdim=['x','y','feature'])

# %%
features_1d.shape
# Out:
# (2224, 2048)

# %%
labels.shape
# Out:
# (2224, 1)

# %%
# now split train and test data
X_train, X_test, y_train, y_test = train_test_split(features_1d, labels, test_size=0.33, random_state=42)

# %%
print(X_train.shape[0], X_test.shape[0], y_train.shape[0], y_test.shape[0]) # quick check
# Out:
# 1490 734 1490 734

# %%
print(X_train.shape, X_test.shape,)
# Out:
# (1490, 2048) (734, 2048)

# %%
# unstack the stacked x, y, features dimensions
X_train = X_train.unstack()
X_test = X_test.unstack()

# %%
print(X_train.shape, X_test.shape,) # back to original
# Out:
# (1490, 32, 32, 2) (734, 32, 32, 2)

# %%
# standardize data
X_train_scaled, scaler_X = scale_da_along_dim(X_train, dim="feature")
X_test_scaled, _ = scale_da_along_dim(X_test, dim="feature", scaler=scaler_X)

y_train_scaled, scaler_Y = scale_da_along_dim(y_train, dim="feature")
y_test_scaled, _ = scale_da_along_dim(y_test, dim="feature", scaler=scaler_Y)

# %%
X_train.isel(starttime=10, feature=0).plot(); plt.show() # quick check
X_train_scaled.isel(starttime=10, feature=0).plot(); plt.show() # quick check

# %%
X_train.isel(starttime=10, feature=1).plot(); plt.show() # quick check
X_train_scaled.isel(starttime=10, feature=1).plot(); plt.show() # quick check

# %%
X_train.isel(feature=0,starttime=15).plot.hist(); plt.show()
X_train_scaled.isel(feature=0,starttime=15).plot.hist(); plt.show()

# %% [markdown]
# Let's proceed to build a simple convolutional neural network that will take images as the input and predict the respective storm's maximum updraft helicity.

# %%
# Set the seed using keras.utils.set_random_seed. This will set:
# 1) `numpy` seed
# 2) backend random seed
# 3) `python` random seed
keras.utils.set_random_seed(12)

# %%
# lets use two input variables (dbz_grid and ctt_grid)
number_of_features = 2 # Let's change it from 2 to 16:

# %%
model = keras.Sequential()

# input
model.add(keras.Input(shape=(32, 32, number_of_features)))  # 32x32 images

# data augmentation layers
model.add(layers.RandomFlip("horizontal_and_vertical"))
model.add(layers.RandomRotation(factor=(-0.5, 0.5)))

# hidden layers
model.add(layers.Conv2D(filters=16, kernel_size=(3,3), strides=1, padding="same", activation="relu"))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.2))

model.add(layers.Conv2D(filters=32, kernel_size=(3,3), strides=1, padding="same", activation="relu"))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.2))

model.add(layers.Conv2D(filters=64, kernel_size=(3,3), strides=1, padding="same", activation="relu"))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.2))

# Now that we have 4x4 feature maps, now apply global max pooling.
model.add(layers.GlobalMaxPooling2D())

# Finally, we add last fully connected (dense) layers
model.add(layers.Dense(32))
model.add(layers.Dense(1, activation="linear"))

# print model summary
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip_3 (RandomFlip)      │ (None, 32, 32, 2)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation_3               │ (None, 32, 32, 2)      │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 32, 32, 16)     │           304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 16, 16, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 16, 16, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 16, 16, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 8, 8, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 8, 8, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling2d_3          │ (None, 64)             │             0 │
# │ (GlobalMaxPooling2D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,553 (99.82 KB)
#  Trainable params: 25,553 (99.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Proceeding with compiling our model and selecting some metrics to use.

# %% [markdown]
# Some common evaluation metrics used with regression problems are:
#
# Mean absolute error (MAE): $\frac{1}{N} \sum\limits_{i = 1}^{N} \lvert \hat{y}_i - y_i \rvert$
#
# Mean squared error (MSE): $\frac{1}{N} \sum\limits_{i = 1}^{N} (\hat{y}_i - y_i)^2$
#
#
# More evalution metrics can be found [here](https://keras.io/api/metrics/regression_metrics/#meansquarederror-class).

# %%
METRICS = [
    keras.metrics.MeanSquaredError(name='mean_squared_error'),
    keras.metrics.RootMeanSquaredError(name='root_mean_squared_error'),
    keras.metrics.MeanAbsoluteError(name="mean_absolute_error"),
]

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mean_squared_error",
    metrics=METRICS
)

# %%
BATCH_SIZE = 32
EPOCHS = 20

# %%
history = model.fit(
    x=X_train_scaled.values,
    y=y_train_scaled.values,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_split=0.1,
    shuffle=True,
)
# Out:
# Epoch 1/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - loss: 0.9875 - mean_absolute_error: 0.7948 - mean_squared_error: 0.9875 - root_mean_squared_error: 0.9903 - val_loss: 0.6338 - val_mean_absolute_error: 0.6602 - val_mean_squared_error: 0.6338 - val_root_mean_squared_error: 0.7961
# Epoch 2/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.5560 - mean_absolute_error: 0.6019 - mean_squared_error: 0.5560 - root_mean_squared_error: 0.7453 - val_loss: 0.5230 - val_mean_absolute_error: 0.5858 - val_mean_squared_error: 0.5230 - val_root_mean_squared_error: 0.7232
# Epoch 3/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.4368 - mean_absolute_error: 0.5258 - mean_squared_error: 0.4368 - root_mean_squared_error: 0.6607 - val_loss: 0.3974 - val_mean_absolute_error: 0.5183 - val_mean_squared_error: 0.3974 - val_root_mean_squared_error: 0.6304
# Epoch 4/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.3396 - mean_absolute_error: 0.4671 - mean_squared_error: 0.3396 - root_mean_squared_error: 0.5825 - val_loss: 0.2942 - val_mean_absolute_error: 0.4449 - val_mean_squared_error: 0.2942 - val_root_mean_squared_error: 0.5424
# Epoch 5/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.2570 - mean_absolute_error: 0.4033 - mean_squared_error: 0.2570 - root_mean_squared_error: 0.5067 - val_loss: 0.2513 - val_mean_absolute_error: 0.4112 - val_mean_squared_error: 0.2513 - val_root_mean_squared_error: 0.5013
# Epoch 6/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 0.2300 - mean_absolute_error: 0.3832 - mean_squared_error: 0.2300 - root_mean_squared_error: 0.4794 - val_loss: 0.2281 - val_mean_absolute_error: 0.3911 - val_mean_squared_error: 0.2281 - val_root_mean_squared_error: 0.4776
# Epoch 7/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.1931 - mean_absolute_error: 0.3462 - mean_squared_error: 0.1931 - root_mean_squared_error: 0.4393 - val_loss: 0.1939 - val_mean_absolute_error: 0.3607 - val_mean_squared_error: 0.1939 - val_root_mean_squared_error: 0.4403
# Epoch 8/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.1944 - mean_absolute_error: 0.3483 - mean_squared_error: 0.1944 - root_mean_squared_error: 0.4408 - val_loss: 0.2283 - val_mean_absolute_error: 0.3867 - val_mean_squared_error: 0.2283 - val_root_mean_squared_error: 0.4778
# Epoch 9/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.1666 - mean_absolute_error: 0.3242 - mean_squared_error: 0.1666 - root_mean_squared_error: 0.4080 - val_loss: 0.2495 - val_mean_absolute_error: 0.3966 - val_mean_squared_error: 0.2495 - val_root_mean_squared_error: 0.4995
# Epoch 10/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.1483 - mean_absolute_error: 0.3003 - mean_squared_error: 0.1483 - root_mean_squared_error: 0.3845 - val_loss: 0.2174 - val_mean_absolute_error: 0.3710 - val_mean_squared_error: 0.2174 - val_root_mean_squared_error: 0.4662
# Epoch 11/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.1540 - mean_absolute_error: 0.3042 - mean_squared_error: 0.1540 - root_mean_squared_error: 0.3913 - val_loss: 0.2153 - val_mean_absolute_error: 0.3658 - val_mean_squared_error: 0.2153 - val_root_mean_squared_error: 0.4640
# Epoch 12/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 0.1485 - mean_absolute_error: 0.2985 - mean_squared_error: 0.1485 - root_mean_squared_error: 0.3852 - val_loss: 0.2104 - val_mean_absolute_error: 0.3635 - val_mean_squared_error: 0.2104 - val_root_mean_squared_error: 0.4587
# Epoch 13/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.1354 - mean_absolute_error: 0.2887 - mean_squared_error: 0.1354 - root_mean_squared_error: 0.3672 - val_loss: 0.2090 - val_mean_absolute_error: 0.3599 - val_mean_squared_error: 0.2090 - val_root_mean_squared_error: 0.4572
# Epoch 14/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.1458 - mean_absolute_error: 0.2966 - mean_squared_error: 0.1458 - root_mean_squared_error: 0.3815 - val_loss: 0.2304 - val_mean_absolute_error: 0.3748 - val_mean_squared_error: 0.2304 - val_root_mean_squared_error: 0.4800
# Epoch 15/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.1255 - mean_absolute_error: 0.2740 - mean_squared_error: 0.1255 - root_mean_squared_error: 0.3540 - val_loss: 0.2443 - val_mean_absolute_error: 0.3835 - val_mean_squared_error: 0.2443 - val_root_mean_squared_error: 0.4943
# Epoch 16/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.1491 - mean_absolute_error: 0.2976 - mean_squared_error: 0.1491 - root_mean_squared_error: 0.3859 - val_loss: 0.1917 - val_mean_absolute_error: 0.3436 - val_mean_squared_error: 0.1917 - val_root_mean_squared_error: 0.4378
# Epoch 17/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.1279 - mean_absolute_error: 0.2756 - mean_squared_error: 0.1279 - root_mean_squared_error: 0.3573 - val_loss: 0.2247 - val_mean_absolute_error: 0.3674 - val_mean_squared_error: 0.2247 - val_root_mean_squared_error: 0.4740
# Epoch 18/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.1377 - mean_absolute_error: 0.2839 - mean_squared_error: 0.1377 - root_mean_squared_error: 0.3706 - val_loss: 0.2414 - val_mean_absolute_error: 0.3777 - val_mean_squared_error: 0.2414 - val_root_mean_squared_error: 0.4913
# Epoch 19/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.1264 - mean_absolute_error: 0.2765 - mean_squared_error: 0.1264 - root_mean_squared_error: 0.3550 - val_loss: 0.2323 - val_mean_absolute_error: 0.3704 - val_mean_squared_error: 0.2323 - val_root_mean_squared_error: 0.4820
# Epoch 20/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.1189 - mean_absolute_error: 0.2647 - mean_squared_error: 0.1189 - root_mean_squared_error: 0.3441 - val_loss: 0.2471 - val_mean_absolute_error: 0.3801 - val_mean_squared_error: 0.2471 - val_root_mean_squared_error: 0.4971

# %%
plt.plot(history.history["loss"], c='k', label='training')
plt.plot(history.history["val_loss"], c='r', label='validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history["mean_squared_error"], c='k', label='training')
plt.plot(history.history["val_mean_squared_error"], c='r', label='validation')
plt.legend()
plt.show()

# %%
# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results = model.evaluate(X_test_scaled.values, y_test_scaled.values, batch_size=y_test_scaled.values.shape[0])
print(results)
# Out:
# Evaluate on test data
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - loss: 0.2690 - mean_absolute_error: 0.3989 - mean_squared_error: 0.2690 - root_mean_squared_error: 0.5187
# [0.2690179944038391, 0.2690179944038391, 0.5186694264411926, 0.39894697070121765]

# %%
# generate predictions using the trained model
predictions = model.predict(X_test_scaled.values)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
# visualize predictions vs ground truth
plt.scatter(predictions, y_test_scaled.values)
plt.show()

# %% [markdown]
# # Tutorial Practice: How does batch size impact model training?
#
# ---

# %%
# recreate the model object

# %%
# recompile the model

# %%
# retrain the model

# %%
# evaluate the new model's skill

# %% [markdown]
# Other sample questions for practice:
#
# *   How does the learning rate impact model training?
# *   Does data augmentation help with model skill?
# *   Does reducing regularization impact overfitting (hint: reduce dropout percentage)?

# %%
# more cells for practicing

# %% [markdown]
# # Supervised Learning Classification Example
#
# ---

# %% [markdown]
# Using our work from the previous section, we will now use the data and reframe our problem to be a classification task. As before, we will use two input features.

# %% [markdown]
# However, we will use updraft helicity values (which represent storm updraft rotation) and convert this continuous value into two classes, "not potentially severe" and "potentially severe". More strongly rotating storms have a greater likelihood of producing severe hazards like tornadoes and large hail. We will use 75 m2/s2 as the delineation mark between the two classes. The two classes will be creating using integer encoding first, with 0 representing non-severe and 1 representing potentially severe, and then converting using one-hot encoding for subsequent training.

# %%
# first contactenate multiple feature into one new array along a dim
tmp_dbz = ds['dbz_grid'].expand_dims(dim='feature', axis=3)
tmp_ctt = ds['ctt_grid'].expand_dims(dim='feature', axis=3)

features = xr.concat([tmp_dbz, tmp_ctt], dim='feature')

# make features, x, and y into one column, so that data is (samples, newdim) for train/test split func to work
features_1d = features.stack(newdim=['x','y','feature'])

labels = ds['uh25_grid'].expand_dims(dim='feature', axis=3).max('x').max('y')

# now split train and test data
X_train, X_test, y_train, y_test = train_test_split(features_1d, labels, test_size=0.33, random_state=42)

# unstack the stacked x, y, features dimensions
X_train = X_train.unstack()
X_test = X_test.unstack()

# standardize data
X_train_scaled, scaler_X = scale_da_along_dim(X_train, dim="feature")
X_test_scaled, _ = scale_da_along_dim(X_test, dim="feature", scaler=scaler_X)

# encode the labels as classes (integer encoding)
y_train_scaled = xr.where(y_train >= 75, 1, 0)
y_test_scaled = xr.where(y_test >= 75, 1, 0)

# %%
print(y_train.values[-5:])
print(y_train_scaled.values[-5:])
# Out:
# [[ 92.49213  ]
#  [  0.7721376]
#  [170.93694  ]
#  [  1.3120162]
#  [ 17.732342 ]]
# [[1]
#  [0]
#  [1]
#  [0]
#  [0]]

# %%
# convert labels into classes using one-hot encoding
onehot_layer = keras.layers.CategoryEncoding(num_tokens=2, output_mode="one_hot")
y_train_onehot = onehot_layer(y_train_scaled.astype(int))
y_test_onehot = onehot_layer(y_test_scaled.astype(int))

# %%
y_train_onehot[-5:]
# Out:
# <tf.Tensor: shape=(5, 2), dtype=float32, numpy=
# array([[0., 1.],
#        [1., 0.],
#        [0., 1.],
#        [1., 0.],
#        [1., 0.]], dtype=float32)>

# %%
# out of more than 1000 samples, only 189 are the "severe" class
print(y_train_onehot[:,1].numpy().sum())
print(y_train_onehot[:,1].numpy().shape)
# Out:
# 180.0
# (1490,)

# %% [markdown]
# Class imbalance is a major issue with a minority class that is a rare event, like severe hazards. To address this limitation, we create class weights that help the machine learning model learn that the minority class is important to get correct.

# %%
# generate class weights due to class imbalance issues
# use the second class as the positive one (using 1 index)
counts = np.bincount(y_train_onehot[:,1].numpy().astype(int))

print("Number of positive samples in training data: {} ({:.2f}% of total)".format(
    counts[1], 100 * float(counts[1]) / len(y_train_onehot[:,1])))

weight_for_0 = counts[1] / len(y_train_onehot[:,1])
weight_for_1 = counts[0] / len(y_train_onehot[:,1])

class_weight = {0: weight_for_0, 1: weight_for_1}
print(class_weight)
# Out:
# Number of positive samples in training data: 180 (12.08% of total)
# {0: np.float64(0.12080536912751678), 1: np.float64(0.8791946308724832)}

# %%
# metrics that are useful for classification, particularly for two classes
METRICS = [
    keras.metrics.BinaryCrossentropy(name="binary_crossentropy"),  # same as model's loss
    keras.metrics.TruePositives(name='tp'),
    keras.metrics.FalsePositives(name='fp'),
    keras.metrics.TrueNegatives(name='tn'),
    keras.metrics.FalseNegatives(name='fn'),
    keras.metrics.BinaryAccuracy(name='accuracy'),
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall'),
    keras.metrics.AUC(name='auc'),
    keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

# %%
model = keras.Sequential()

# input
model.add(keras.Input(shape=(32, 32, number_of_features)))  # 32x32 images

# data augmentation layers
model.add(layers.RandomFlip("horizontal_and_vertical"))
model.add(layers.RandomRotation(factor=(-0.5,0.5)))

# hidden layers
model.add(layers.Conv2D(32, 3, strides=1, padding="same", activation="relu"))
model.add(layers.MaxPooling2D(2))
model.add(layers.Dropout(0.2))

model.add(layers.Conv2D(64, 3, strides=1, padding="same", activation="relu"))
model.add(layers.MaxPooling2D(2))
model.add(layers.Dropout(0.2))

model.add(layers.Conv2D(128, 3, strides=1, padding="same", activation="relu"))
model.add(layers.MaxPooling2D(2))
model.add(layers.Dropout(0.2))

# Now that we have 4x4 feature maps, now apply global max pooling.
model.add(layers.GlobalMaxPooling2D())

# Finally, we add last fully connected (dense) layers
model.add(layers.Dense(64))
model.add(layers.Dense(2, activation="softmax"))

# print model summary
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip_4 (RandomFlip)      │ (None, 32, 32, 2)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation_4               │ (None, 32, 32, 2)      │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 32, 32, 32)     │           608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling2d_4          │ (None, 128)            │             0 │
# │ (GlobalMaxPooling2D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,346 (395.88 KB)
#  Trainable params: 101,346 (395.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss=keras.losses.BinaryCrossentropy(), # categorical loss function
    metrics=METRICS
)

# %%
BATCH_SIZE = 32
EPOCHS = 20

# %%
print("Fit model on training data")
history = model.fit(
    x=X_train_scaled.values,
    y=y_train_onehot,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_split=0.1,
    shuffle=True,
    class_weight=class_weight,
)
# Out:
# Fit model on training data
# Epoch 1/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 9s 111ms/step - accuracy: 0.6423 - auc: 0.7179 - binary_crossentropy: 0.6275 - fn: 277.1628 - fp: 277.1628 - loss: 0.1380 - prc: 0.7171 - precision: 0.6423 - recall: 0.6423 - tn: 425.9535 - tp: 425.9535 - val_accuracy: 0.5973 - val_auc: 0.7486 - val_binary_crossentropy: 0.5481 - val_fn: 60.0000 - val_fp: 60.0000 - val_loss: 0.5481 - val_prc: 0.7861 - val_precision: 0.5973 - val_recall: 0.5973 - val_tn: 89.0000 - val_tp: 89.0000
# Epoch 2/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - accuracy: 0.5912 - auc: 0.7334 - binary_crossentropy: 0.5774 - fn: 294.9767 - fp: 294.9767 - loss: 0.1120 - prc: 0.7676 - precision: 0.5912 - recall: 0.5912 - tn: 408.1395 - tp: 408.1395 - val_accuracy: 0.7517 - val_auc: 0.8514 - val_binary_crossentropy: 0.4826 - val_fn: 37.0000 - val_fp: 37.0000 - val_loss: 0.4826 - val_prc: 0.8605 - val_precision: 0.7517 - val_recall: 0.7517 - val_tn: 112.0000 - val_tp: 112.0000
# Epoch 3/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.6857 - auc: 0.8068 - binary_crossentropy: 0.4987 - fn: 233.7442 - fp: 233.7442 - loss: 0.0975 - prc: 0.8257 - precision: 0.6857 - recall: 0.6857 - tn: 469.3721 - tp: 469.3721 - val_accuracy: 0.8926 - val_auc: 0.9532 - val_binary_crossentropy: 0.3866 - val_fn: 16.0000 - val_fp: 16.0000 - val_loss: 0.3866 - val_prc: 0.9549 - val_precision: 0.8926 - val_recall: 0.8926 - val_tn: 133.0000 - val_tp: 133.0000
# Epoch 4/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - accuracy: 0.7637 - auc: 0.8607 - binary_crossentropy: 0.4477 - fn: 173.0465 - fp: 173.0465 - loss: 0.0883 - prc: 0.8680 - precision: 0.7637 - recall: 0.7637 - tn: 530.0698 - tp: 530.0698 - val_accuracy: 0.8725 - val_auc: 0.9522 - val_binary_crossentropy: 0.3574 - val_fn: 19.0000 - val_fp: 19.0000 - val_loss: 0.3574 - val_prc: 0.9529 - val_precision: 0.8725 - val_recall: 0.8725 - val_tn: 130.0000 - val_tp: 130.0000
# Epoch 5/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - accuracy: 0.8394 - auc: 0.9132 - binary_crossentropy: 0.3766 - fn: 119.2093 - fp: 119.2093 - loss: 0.0755 - prc: 0.9134 - precision: 0.8394 - recall: 0.8394 - tn: 583.9070 - tp: 583.9070 - val_accuracy: 0.9463 - val_auc: 0.9843 - val_binary_crossentropy: 0.2874 - val_fn: 8.0000 - val_fp: 8.0000 - val_loss: 0.2874 - val_prc: 0.9849 - val_precision: 0.9463 - val_recall: 0.9463 - val_tn: 141.0000 - val_tp: 141.0000
# Epoch 6/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - accuracy: 0.8613 - auc: 0.9267 - binary_crossentropy: 0.3505 - fn: 101.8605 - fp: 101.8605 - loss: 0.0710 - prc: 0.9228 - precision: 0.8613 - recall: 0.8613 - tn: 601.2558 - tp: 601.2558 - val_accuracy: 0.9329 - val_auc: 0.9792 - val_binary_crossentropy: 0.2056 - val_fn: 10.0000 - val_fp: 10.0000 - val_loss: 0.2056 - val_prc: 0.9790 - val_precision: 0.9329 - val_recall: 0.9329 - val_tn: 139.0000 - val_tp: 139.0000
# Epoch 7/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - accuracy: 0.8922 - auc: 0.9406 - binary_crossentropy: 0.3013 - fn: 79.8140 - fp: 79.8140 - loss: 0.0706 - prc: 0.9330 - precision: 0.8922 - recall: 0.8922 - tn: 623.3023 - tp: 623.3023 - val_accuracy: 0.9530 - val_auc: 0.9833 - val_binary_crossentropy: 0.2209 - val_fn: 7.0000 - val_fp: 7.0000 - val_loss: 0.2209 - val_prc: 0.9837 - val_precision: 0.9530 - val_recall: 0.9530 - val_tn: 142.0000 - val_tp: 142.0000
# Epoch 8/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.9075 - auc: 0.9577 - binary_crossentropy: 0.2611 - fn: 71.3953 - fp: 71.3953 - loss: 0.0614 - prc: 0.9517 - precision: 0.9075 - recall: 0.9075 - tn: 631.7209 - tp: 631.7209 - val_accuracy: 0.9530 - val_auc: 0.9916 - val_binary_crossentropy: 0.1783 - val_fn: 7.0000 - val_fp: 7.0000 - val_loss: 0.1783 - val_prc: 0.9918 - val_precision: 0.9530 - val_recall: 0.9530 - val_tn: 142.0000 - val_tp: 142.0000
# Epoch 9/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.9002 - auc: 0.9412 - binary_crossentropy: 0.2934 - fn: 75.8837 - fp: 75.8837 - loss: 0.0693 - prc: 0.9314 - precision: 0.9002 - recall: 0.9002 - tn: 627.2325 - tp: 627.2325 - val_accuracy: 0.9732 - val_auc: 0.9937 - val_binary_crossentropy: 0.1732 - val_fn: 4.0000 - val_fp: 4.0000 - val_loss: 0.1732 - val_prc: 0.9939 - val_precision: 0.9732 - val_recall: 0.9732 - val_tn: 145.0000 - val_tp: 145.0000
# Epoch 10/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - accuracy: 0.9199 - auc: 0.9652 - binary_crossentropy: 0.2397 - fn: 64.1395 - fp: 64.1395 - loss: 0.0630 - prc: 0.9602 - precision: 0.9199 - recall: 0.9199 - tn: 638.9767 - tp: 638.9767 - val_accuracy: 0.9597 - val_auc: 0.9877 - val_binary_crossentropy: 0.1968 - val_fn: 6.0000 - val_fp: 6.0000 - val_loss: 0.1968 - val_prc: 0.9876 - val_precision: 0.9597 - val_recall: 0.9597 - val_tn: 143.0000 - val_tp: 143.0000
# Epoch 11/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - accuracy: 0.9209 - auc: 0.9647 - binary_crossentropy: 0.2391 - fn: 62.0698 - fp: 62.0698 - loss: 0.0619 - prc: 0.9580 - precision: 0.9209 - recall: 0.9209 - tn: 641.0465 - tp: 641.0465 - val_accuracy: 0.9530 - val_auc: 0.9812 - val_binary_crossentropy: 0.2075 - val_fn: 7.0000 - val_fp: 7.0000 - val_loss: 0.2075 - val_prc: 0.9803 - val_precision: 0.9530 - val_recall: 0.9530 - val_tn: 142.0000 - val_tp: 142.0000
# Epoch 12/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - accuracy: 0.9272 - auc: 0.9680 - binary_crossentropy: 0.2161 - fn: 58.3023 - fp: 58.3023 - loss: 0.0562 - prc: 0.9629 - precision: 0.9272 - recall: 0.9272 - tn: 644.8140 - tp: 644.8140 - val_accuracy: 0.9530 - val_auc: 0.9853 - val_binary_crossentropy: 0.2150 - val_fn: 7.0000 - val_fp: 7.0000 - val_loss: 0.2150 - val_prc: 0.9856 - val_precision: 0.9530 - val_recall: 0.9530 - val_tn: 142.0000 - val_tp: 142.0000
# Epoch 13/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.9189 - auc: 0.9655 - binary_crossentropy: 0.2343 - fn: 62.8837 - fp: 62.8837 - loss: 0.0615 - prc: 0.9597 - precision: 0.9189 - recall: 0.9189 - tn: 640.2325 - tp: 640.2325 - val_accuracy: 0.9530 - val_auc: 0.9762 - val_binary_crossentropy: 0.2225 - val_fn: 7.0000 - val_fp: 7.0000 - val_loss: 0.2225 - val_prc: 0.9750 - val_precision: 0.9530 - val_recall: 0.9530 - val_tn: 142.0000 - val_tp: 142.0000
# Epoch 14/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - accuracy: 0.9288 - auc: 0.9716 - binary_crossentropy: 0.2154 - fn: 54.3488 - fp: 54.3488 - loss: 0.0522 - prc: 0.9679 - precision: 0.9288 - recall: 0.9288 - tn: 648.7675 - tp: 648.7675 - val_accuracy: 0.9530 - val_auc: 0.9796 - val_binary_crossentropy: 0.1891 - val_fn: 7.0000 - val_fp: 7.0000 - val_loss: 0.1891 - val_prc: 0.9739 - val_precision: 0.9530 - val_recall: 0.9530 - val_tn: 142.0000 - val_tp: 142.0000
# Epoch 15/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - accuracy: 0.9294 - auc: 0.9696 - binary_crossentropy: 0.2047 - fn: 55.1395 - fp: 55.1395 - loss: 0.0562 - prc: 0.9628 - precision: 0.9294 - recall: 0.9294 - tn: 647.9767 - tp: 647.9767 - val_accuracy: 0.9530 - val_auc: 0.9852 - val_binary_crossentropy: 0.1906 - val_fn: 7.0000 - val_fp: 7.0000 - val_loss: 0.1906 - val_prc: 0.9838 - val_precision: 0.9530 - val_recall: 0.9530 - val_tn: 142.0000 - val_tp: 142.0000
# Epoch 16/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - accuracy: 0.9272 - auc: 0.9702 - binary_crossentropy: 0.2120 - fn: 56.7442 - fp: 56.7442 - loss: 0.0520 - prc: 0.9656 - precision: 0.9272 - recall: 0.9272 - tn: 646.3721 - tp: 646.3721 - val_accuracy: 0.9396 - val_auc: 0.9681 - val_binary_crossentropy: 0.2330 - val_fn: 9.0000 - val_fp: 9.0000 - val_loss: 0.2330 - val_prc: 0.9614 - val_precision: 0.9396 - val_recall: 0.9396 - val_tn: 140.0000 - val_tp: 140.0000
# Epoch 17/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - accuracy: 0.9416 - auc: 0.9697 - binary_crossentropy: 0.1952 - fn: 45.7674 - fp: 45.7674 - loss: 0.0493 - prc: 0.9623 - precision: 0.9416 - recall: 0.9416 - tn: 657.3488 - tp: 657.3488 - val_accuracy: 0.9396 - val_auc: 0.9772 - val_binary_crossentropy: 0.2070 - val_fn: 9.0000 - val_fp: 9.0000 - val_loss: 0.2070 - val_prc: 0.9708 - val_precision: 0.9396 - val_recall: 0.9396 - val_tn: 140.0000 - val_tp: 140.0000
# Epoch 18/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - accuracy: 0.9358 - auc: 0.9741 - binary_crossentropy: 0.1947 - fn: 52.3488 - fp: 52.3488 - loss: 0.0526 - prc: 0.9694 - precision: 0.9358 - recall: 0.9358 - tn: 650.7675 - tp: 650.7675 - val_accuracy: 0.9396 - val_auc: 0.9723 - val_binary_crossentropy: 0.2266 - val_fn: 9.0000 - val_fp: 9.0000 - val_loss: 0.2266 - val_prc: 0.9635 - val_precision: 0.9396 - val_recall: 0.9396 - val_tn: 140.0000 - val_tp: 140.0000
# Epoch 19/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.9345 - auc: 0.9678 - binary_crossentropy: 0.2167 - fn: 52.3488 - fp: 52.3488 - loss: 0.0554 - prc: 0.9606 - precision: 0.9345 - recall: 0.9345 - tn: 650.7675 - tp: 650.7675 - val_accuracy: 0.9463 - val_auc: 0.9797 - val_binary_crossentropy: 0.2073 - val_fn: 8.0000 - val_fp: 8.0000 - val_loss: 0.2073 - val_prc: 0.9735 - val_precision: 0.9463 - val_recall: 0.9463 - val_tn: 141.0000 - val_tp: 141.0000
# Epoch 20/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - accuracy: 0.9238 - auc: 0.9665 - binary_crossentropy: 0.2169 - fn: 57.7442 - fp: 57.7442 - loss: 0.0562 - prc: 0.9613 - precision: 0.9238 - recall: 0.9238 - tn: 645.3721 - tp: 645.3721 - val_accuracy: 0.9396 - val_auc: 0.9675 - val_binary_crossentropy: 0.2466 - val_fn: 9.0000 - val_fp: 9.0000 - val_loss: 0.2466 - val_prc: 0.9580 - val_precision: 0.9396 - val_recall: 0.9396 - val_tn: 140.0000 - val_tp: 140.0000

# %%
plt.plot(history.history["loss"], c='k', label='training')
plt.plot(history.history["val_loss"], c='r', label='validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.show()

# %%
# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results = model.evaluate(X_test_scaled.values, y_test_onehot, batch_size=y_test_onehot.shape[0])
print(results)
# Out:
# Evaluate on test data
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step - accuracy: 0.9264 - auc: 0.9594 - binary_crossentropy: 0.2566 - fn: 54.0000 - fp: 54.0000 - loss: 0.2566 - prc: 0.9499 - precision: 0.9264 - recall: 0.9264 - tn: 680.0000 - tp: 680.0000
# [0.25658226013183594, 0.25658226013183594, 680.0, 54.0, 680.0, 54.0, 0.9264305233955383, 0.9264305233955383, 0.9264305233955383, 0.9594408273696899, 0.9498633146286011]

# %%
# generate predictions using the trained model
predictions = model.predict(X_test_scaled.values)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step

# %%
pred_ints = xr.where(predictions[:,1] > 0.5, 1, 0)

# %%
from sklearn.metrics.cluster import contingency_matrix
contingency_matrix(y_test_onehot[:,1].numpy().astype(int), pred_ints)
# Out:
# array([[586,  47],
#        [  7,  94]])

# %% [markdown]
# TP (true positive) = true 1, pred 1 = 90
#
# FN (false negative) = true 1, pred 0 = 11
#
# FP (false positive) = true 0, pred 1 = 42
#
# TN (true negative) = true 0, pred 0 = 591

# %%
y_test_onehot[:,1].numpy().astype(int).sum()
# Out:
# np.int64(101)

# %%
pred_ints.sum() - 101
# Out:
# np.int64(40)

# %% [markdown]
# ```
# y_test_onehot[:,1].sum() = number of actual positives
# = TP + FN = 90 + 11 = 101
#
# pred_ints.sum() = number of predicted positives
# = TP + FP = 90 + 42 = 132
# ```
# That 31 is not FP itself; it is the net excess of positive predictions over true positives: you have 42 false positives but only 11 false negatives, so you end up predicting 31 more “1”s than are actually present in the ground truth.

# %% [markdown]
# # Tutorial Practice: What happens if we do not use class weights during training?
#
# ---

# %%
# recreate the model object

# %%
# recompile the model

# %%
# retrain the model without class weights

# %%
# evaluate the new model's skill

# %% [markdown]
# # References
#
# Campbell, T., G. M. Lackmann, M. J. Molina, and M. D. Parker (2024). Severe Convective Storms in Limited Instability Organized by Pattern and Distribution. Weather and Forecasting. https://journals.ametsoc.org/view/journals/wefo/39/1/WAF-D-23-0130.1.xml
#
# DuVivier, A. K., M. J. Molina, A. L. Deppenmeier, M. M. Holland, L. Landrum, K. Krumhardt, and S. Jenouvrier (2023). Projections of Winter Polynyas and Their Biophysical Impacts in the Ross Sea Antarctica. Climate Dynamics. https://link.springer.com/article/10.1007/s00382-023-06951-z
#
# Molina, M. J., D. J. Gagne, and A. F. Prein (2021). A benchmark to test generalization capabilities of deep learning methods to classify severe convective storms in a changing climate. Earth and Space Science. https://agupubs.onlinelibrary.wiley.com/doi/full/10.1029/2020EA001490
#
# Molina, M. J., T. A. O'Brien, G. Anderson, M. Ashfaq, K. E. Bennett, W. D. Collins, K. Dagon, J. M. Restrepo, and P. A. Ullrich (2023). A Review of Recent and Emerging Machine Learning Applications for Climate Variability and Weather Phenomena. Artificial Intelligence for the Earth Systems. https://journals.ametsoc.org/view/journals/aies/2/4/AIES-D-22-0086.1.xml
#
# Molina, M. J., J. H. Richter, A. A. Glanville, K. Dagon, J. Berner, A. Hu, and G. A. Meehl (2023). Subseasonal Representation and Predictability of North American Weather Regimes using Cluster Analysis. Artificial Intelligence for the Earth Systems. https://journals.ametsoc.org/view/journals/aies/2/2/AIES-D-22-0051.1.xml
#
# Passarella, L.S. and Mahajan, S., 2023. Assessing Tropical Pacific–Induced Predictability of Southern California Precipitation Using a Novel Multi-Input Multioutput Autoencoder. Artificial Intelligence for the Earth Systems, 2(4), p.e230003. https://journals.ametsoc.org/view/journals/aies/2/4/AIES-D-23-0003.1.xml
